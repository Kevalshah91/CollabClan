# %%
print("Card_Wars")
# Out:
# Card_Wars

# %%
# CARD
# SUIT,RANK,VAlue
# DECK
# PLAYER
# GAME_LOGIC

# %%
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card:
    def __init__(self,suit,rank):
        self.rank = rank
        self.suit = suit
        self.value = values[rank]
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
ace_spades = Card("spades","Ace")
print(ace_spades)
# Out:
# Ace of spades

# %%
ace_spades.suit
# Out:
# 'spades'

# %%
five_hearts = Card("hearts","Five")

# %%
five_hearts.value
# Out:
# 5

# %%
ace_spades.value >five_hearts.value
# Out:
# True

# %%
two_hearts = Card(suits[0],ranks[0])
print(two_hearts)
# Out:
# Two of Hearts

# %%
import random

# %%
class Deck:
    def __init__(self):
        self.all_cards = []
        for suit in suits:
            for rank in ranks:
                self.all_cards.append(Card(suit,rank))
    def shuffle(self):
        random.shuffle(self.all_cards)
    def deal(self):
        if len(self.all_cards) > 0:
            return self.all_cards.pop()
        else:
            print("No more cards in the deck.")
            return None

# %%
myDeck = Deck()

# %%
len(myDeck.all_cards)
# Out:
# 52

# %%
myDeck.all_cards[0]

# %%
print(myDeck.all_cards[5])
# Out:
# Seven of Hearts

# %%
bottom_card = myDeck.all_cards[-1]
print(bottom_card)
# Out:
# Ace of Clubs

# %%
myCard = myDeck.deal()

# %%
print(myCard)
# Out:
# Ace of Clubs

# %%
newDeck = Deck()

# %%
newDeck.shuffle()

# %%
print(newDeck.all_cards[0])
# Out:
# Four of Hearts

# %%
class Player:
    def __init__(self, name):
        self.name = name
        self.all_cards = []
    def remove_one(self):
        if self.all_cards:
            return self.all_cards.pop(0)
        else:
            print(f"{self.name} has no cards to remove.")
            return None
    def add_cards(self, new_cards):
        if isinstance(new_cards, list):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards.'

# %%
newPlayer = Player('Keval')

# %%
print(newPlayer)
# Out:
# Player Keval has 0 cards.

# %%
newPlayer.add_cards(myCard)

# %%
print(myCard)
# Out:
# Ace of Clubs

# %%
print(newPlayer)
# Out:
# Player Keval has 1 cards.

# %%
newPlayer.add_cards([two_hearts,two_hearts,two_hearts])

# %%
print(newPlayer)
# Out:
# Player Keval has 4 cards.

# %%
player_one = Player("One")
player_two = Player("Two")

# %%
new_deck = Deck()

# %%
new_deck.shuffle()

# %%
len(new_deck.all_cards)
# Out:
# 52

# %%
for x in range(26):
    player_one.add_cards(new_deck.deal())
    player_two.add_cards(new_deck.deal())

# %%
len(player_one.all_cards)
# Out:
# 26

# %%
print(player_one)
# Out:
# Player One has 26 cards.

# %%
len(player_two.all_cards)
# Out:
# 26

# %%
print(player_two)
# Out:
# Player Two has 26 cards.

# %%
len(new_deck.all_cards)
# Out:
# 0

# %%
game_ON = True

# %%
round_num = 0
while game_ON:
    round_num += 1
    print(f"Round {round_num}")
    
    if len(player_one.all_cards) == 0:
        print("Player 1 out of cards ! ")
        print("GAME OVER !!!")
        print("WINNER : Player2")
        game_ON = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player 2 out of cards ! ")
        print("GAME OVER !!!")
        print("WINNER : Player1")
        game_ON = False
        break
        
    player_one_cards = []
    removed_card = player_one.remove_one()
    if removed_card is not None:
        player_one_cards.append(removed_card)
    
    player_two_cards = []
    removed_card = player_two.remove_one()
    if removed_card is not None:
        player_two_cards.append(removed_card)
    
    war = True
    while war:
        if len(player_one_cards) > 0 and len(player_two_cards) > 0:
            if player_one_cards[-1].value > player_two_cards[-1].value:
                player_one.add_cards(player_one_cards)
                player_one.add_cards(player_two_cards)
                war = False
            elif player_one_cards[-1].value < player_two_cards[-1].value:
                player_two.add_cards(player_one_cards)
                player_two.add_cards(player_two_cards)
                war = False
            else:
                print('WAR!')
                if len(player_one.all_cards) < 5:
                    print("Player One unable to play war! Game Over at War")
                    print("Player Two Wins! Player One Loses!")
                    game_on = False
                    break
                elif len(player_two.all_cards) < 5:
                    print("Player Two unable to play war! Game Over at War")
                    print("Player One Wins! Player One Loses!")
                    game_on = False
                    break
                else:
                    for num in range(5):
                        player_one_cards.append(player_one.remove_one())
                        player_two_cards.append(player_two.remove_one())
        else:
            print("One of the players ran out of cards during war. Game Over!")
            game_on = False
            break
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# WAR!
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# WAR!
# Round 28
# Round 29
# Round 30
# WAR!
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# Round 42
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# Round 81
# Round 82
# Round 83
# Round 84
# Round 85
# Round 86
# Round 87
# Round 88
# Round 89
# ...

# %%
print(player_one_cards[-1])
# Out:
# Three of Spades

# %%
player_one_cards[-1].value
# Out:
# 3

# %%
len(player_one.all_cards)
# Out:
# 0

# %%
len(player_two.all_cards)
# Out:
# 50
